# %% [markdown]
# # Q4 Stock Prediction

# %% [markdown]
# ## Dataset
#
# Download dataset from [Yahoo! Finance](https://finance.yahoo.com/):
#
# * AAPL: https://finance.yahoo.com/quote/ADAP/history?p=ADAP
# * PG: https://finance.yahoo.com/quote/PG/history?p=PG
# * GM: https://finance.yahoo.com/quote/GM/history?p=GM
#
# ## Reference
#
# Code Reference on Github, using LSTM model to predict stock closing price on June 2, 2020.
#
# https://github.com/huseinzol05/Stock-Prediction-Models

# %%
import sys
import warnings

if not sys.warnoptions:
    warnings.simplefilter('ignore')

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from datetime import datetime
from datetime import timedelta
from tqdm import tqdm
sns.set()
tf.compat.v1.random.set_random_seed(1234)

# %%
df = pd.read_csv('dataset/AAPL.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2019-05-30  177.949997  179.229996  176.669998  178.300003  176.197189
# 1  2019-05-31  176.229996  177.990005  174.990005  175.070007  173.005280
# 2  2019-06-03  175.600006  177.919998  170.270004  173.300003  171.256134
# 3  2019-06-04  175.440002  179.830002  174.520004  179.639999  177.521378
# 4  2019-06-05  184.279999  184.990005  181.139999  182.539993  180.387146
#
#      Volume
# 0  21218400
# 1  27043600
# 2  40396100
# 3  30968000
# 4  29773400

# %% [markdown]
# ## Forecast
#
# I use LSTM model to do prediction.
#
# * `test_size`. How many days ahead you want to forecast. Here I set 30 days, including June 2, 2020.
# * `simulation_size`. The simulation times, here I simulate three times.

# %%
# Initialize parameters
simulation_size = 3
num_layers = 1
size_layer = 128
timestamp = 5
epoch = 300
dropout_rate = 0.8
test_size = 30
learning_rate = 0.01

# %%
# Build training dataframe
minmax = MinMaxScaler().fit(df.iloc[:, 4:5].astype('float32')) # Close index
df_log = minmax.transform(df.iloc[:, 4:5].astype('float32')) # Close index
df_log = pd.DataFrame(df_log)
df_train = df_log
df.shape, df_train.shape
# Out:
# ((253, 7), (253, 1))

# %%
class Model:
    def __init__(
        self,
        learning_rate,
        num_layers,
        size,
        size_layer,
        output_size,
        forget_bias = 0.1,
    ):
        def lstm_cell(size_layer):
            return tf.nn.rnn_cell.LSTMCell(size_layer, state_is_tuple = False)

        rnn_cells = tf.nn.rnn_cell.MultiRNNCell(
            [lstm_cell(size_layer) for _ in range(num_layers)],
            state_is_tuple = False,
        )
        self.X = tf.placeholder(tf.float32, (None, None, size))
        self.Y = tf.placeholder(tf.float32, (None, output_size))
        drop = tf.contrib.rnn.DropoutWrapper(
            rnn_cells, output_keep_prob = forget_bias
        )
        self.hidden_layer = tf.placeholder(
            tf.float32, (None, num_layers * 2 * size_layer)
        )
        self.outputs, self.last_state = tf.nn.dynamic_rnn(
            drop, self.X, initial_state = self.hidden_layer, dtype = tf.float32
        )
        self.logits = tf.layers.dense(self.outputs[-1], output_size)
        self.cost = tf.reduce_mean(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.AdamOptimizer(learning_rate).minimize(
            self.cost
        )
        
def calculate_accuracy(real, predict):
    real = np.array(real) + 1
    predict = np.array(predict) + 1
    percentage = 1 - np.sqrt(np.mean(np.square((real - predict) / real)))
    return percentage * 100

def anchor(signal, weight):
    buffer = []
    last = signal[0]
    for i in signal:
        smoothed_val = last * weight + (1 - weight) * i
        buffer.append(smoothed_val)
        last = smoothed_val
    return buffer

# %%
def forecast():
    tf.reset_default_graph()
    modelnn = Model(
        learning_rate, num_layers, df_log.shape[1], size_layer, df_log.shape[1], dropout_rate
    )
    sess = tf.InteractiveSession()
    sess.run(tf.global_variables_initializer())
    date_ori = pd.to_datetime(df.iloc[:, 0]).tolist()

    pbar = tqdm(range(epoch), desc = 'train loop')
    for i in pbar:
        init_value = np.zeros((1, num_layers * 2 * size_layer))
        total_loss, total_acc = [], []
        for k in range(0, df_train.shape[0] - 1, timestamp):
            index = min(k + timestamp, df_train.shape[0] - 1)
            batch_x = np.expand_dims(
                df_train.iloc[k : index, :].values, axis = 0
            )
            batch_y = df_train.iloc[k + 1 : index + 1, :].values
            logits, last_state, _, loss = sess.run(
                [modelnn.logits, modelnn.last_state, modelnn.optimizer, modelnn.cost],
                feed_dict = {
                    modelnn.X: batch_x,
                    modelnn.Y: batch_y,
                    modelnn.hidden_layer: init_value,
                },
            )        
            init_value = last_state
            total_loss.append(loss)
            total_acc.append(calculate_accuracy(batch_y[:, 0], logits[:, 0]))
        pbar.set_postfix(cost = np.mean(total_loss), acc = np.mean(total_acc))
    
    future_day = test_size

    output_predict = np.zeros((df_train.shape[0] + future_day, df_train.shape[1]))
    output_predict[0] = df_train.iloc[0]
    upper_b = (df_train.shape[0] // timestamp) * timestamp
    init_value = np.zeros((1, num_layers * 2 * size_layer))

    for k in range(0, (df_train.shape[0] // timestamp) * timestamp, timestamp):
        out_logits, last_state = sess.run(
            [modelnn.logits, modelnn.last_state],
            feed_dict = {
                modelnn.X: np.expand_dims(
                    df_train.iloc[k : k + timestamp], axis = 0
                ),
                modelnn.hidden_layer: init_value,
            },
        )
        init_value = last_state
        output_predict[k + 1 : k + timestamp + 1] = out_logits

    if upper_b != df_train.shape[0]:
        out_logits, last_state = sess.run(
            [modelnn.logits, modelnn.last_state],
            feed_dict = {
                modelnn.X: np.expand_dims(df_train.iloc[upper_b:], axis = 0),
                modelnn.hidden_layer: init_value,
            },
        )
        output_predict[upper_b + 1 : df_train.shape[0] + 1] = out_logits
        future_day -= 1
        date_ori.append(date_ori[-1] + timedelta(days = 1))

    init_value = last_state
    
    for i in range(future_day):
        o = output_predict[-future_day - timestamp + i:-future_day + i]
        out_logits, last_state = sess.run(
            [modelnn.logits, modelnn.last_state],
            feed_dict = {
                modelnn.X: np.expand_dims(o, axis = 0),
                modelnn.hidden_layer: init_value,
            },
        )
        init_value = last_state
        output_predict[-future_day + i] = out_logits[-1]
        date_ori.append(date_ori[-1] + timedelta(days = 1))
    
    output_predict = minmax.inverse_transform(output_predict)
    deep_future = anchor(output_predict[:, 0], 0.4)
    
    return deep_future

# %% [markdown]
# ## Sanity check
#
# Some of our models might not have stable gradient, so forecasted trend might really hangwired. You can use many methods to filter out unstable models.
#
# This method is very simple,
# 1. If one of element in forecasted trend lower than min(original trend).
# 2. If one of element in forecasted trend bigger than max(original trend) * 2.
#
# If both are true, reject that trend.

# %%
def sanity_check(pred_stock):
    if (np.array(pred_stock[-test_size:]) < np.min(df['Close'])).sum() == 0 and \
        (np.array(pred_stock[-test_size:]) > np.max(df['Close']) * 2).sum() == 0:
        return True
    else:
        return False

# %% [markdown]
# ## Visualize the stock price

# %%
def visualize(pred_stock):
    accuracies = calculate_accuracy(df['Close'].values, pred_stock[:-test_size])

    plt.figure(figsize = (15, 5))

    plt.plot(pred_stock, label = 'forecast %d'%(no + 1))
    plt.plot(df['Close'], label = 'true trend', c = 'black')
    plt.legend()
    plt.title('average accuracy: %.4f'%(np.mean(accuracies)))

    x_range_future = np.arange(len(results[0]))
    plt.xticks(x_range_future[::30], date_ori[::30])

    plt.show()

# %%
# Generate the date series from 2019-05-30 to 2020-06-28
date_ori = pd.to_datetime(df.iloc[:, 0]).tolist()
for i in range(test_size):
    date_ori.append(date_ori[-1] + timedelta(days = 1))
date_ori = pd.Series(date_ori).dt.strftime(date_format = '%Y-%m-%d').tolist()

# %% [markdown]
# ## Forcast AAPL Stock Price

# %%
# Read data from CSV and build training dataframe
df = pd.read_csv('dataset/AAPL.csv')
minmax = MinMaxScaler().fit(df.iloc[:, 4:5].astype('float32')) # Close index
df_log = minmax.transform(df.iloc[:, 4:5].astype('float32')) # Close index
df_log = pd.DataFrame(df_log)
df_train = df_log
df.shape, df_train.shape
# Out:
# ((253, 7), (253, 1))

# %%
# Forcasting the future price
pred_stock_AAPL = forecast()

# %%
# Check this model if stable, if True then keep the model. Otherwise, we need to retrain a model
sanity_check(pred_stock_AAPL)
# Out:
# True

# %%
# See the forcasted stock closing price
[list(i) for i in zip(date_ori, pred_stock_AAPL)][-30:]
# Out:
# [['2020-05-30', 318.320753964645],
#  ['2020-05-31', 315.37668390533815],
#  ['2020-06-01', 314.9733600923256],
#  ['2020-06-02', 313.3019549021752],
#  ['2020-06-03', 315.7215282451331],
#  ['2020-06-04', 316.48966532829127],
#  ['2020-06-05', 316.8547220482138],
#  ['2020-06-06', 318.52002291060194],
#  ['2020-06-07', 322.2875100338905],
#  ['2020-06-08', 323.0996878984653],
#  ['2020-06-09', 326.64052788737973],
#  ['2020-06-10', 333.40851942229267],
#  ['2020-06-11', 343.91538219686885],
#  ['2020-06-12', 355.13211270930196],
#  ['2020-06-13', 353.64072927130667],
#  ['2020-06-14', 357.5423647284763],
#  ['2020-06-15', 331.54797561564305],
#  ['2020-06-16', 282.70409202287044],
#  ['2020-06-17', 290.9506346539014],
#  ['2020-06-18', 299.8856236422407],
#  ['2020-06-19', 305.51323187805315],
#  ['2020-06-20', 321.00473792702417],
#  ['2020-06-21', 337.5129613599869],
#  ['2020-06-22', 337.27909441213353],
#  ['2020-06-23', 315.0024472270693],
# ...

# %%
visualize(pred_stock_AAPL)

# %% [markdown]
# ## Forcast PG Stock Price

# %%
# Read data from CSV and build training dataframe
df = pd.read_csv('dataset/PG.csv')
minmax = MinMaxScaler().fit(df.iloc[:, 4:5].astype('float32')) # Close index
df_log = minmax.transform(df.iloc[:, 4:5].astype('float32')) # Close index
df_log = pd.DataFrame(df_log)
df_train = df_log
df.shape, df_train.shape
# Out:
# ((253, 7), (253, 1))

# %%
# Forcasting the future price
pred_stock_PG = forecast()
# Out:
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x000001C1B19380F0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# ...
# train loop:  66%|█████████████████████████████▋               | 198/300 [01:45<01:02,  1.64it/s, acc=96.1, cost=0.0056]
# ...
# ...
# train loop: 100%|████████████████████████████████████████████| 300/300 [02:40<00:00,  1.87it/s, acc=96.2, cost=0.00482]

# %%
# Check this model if stable, if True, we keep the model. If false, we need to retrain a model until the sanity check passes.
sanity_check(pred_stock_AAPL)
# Out:
# False

# %% [markdown]
# However this `PG stock` always *makes the model failed* to pass sanity check. To analyse the stock price curve, we find that the stock price sharply droped during February to April which makes LSTM model hard to fit.

# %%
# See the forcasted stock closing price
[list(i) for i in zip(date_ori, pred_stock_PG)][-30:]
# Out:
# [['2020-05-30', 115.30464576496401],
#  ['2020-05-31', 115.63267604263771],
#  ['2020-06-01', 115.71343526866384],
#  ['2020-06-02', 115.84059501552453],
#  ['2020-06-03', 115.60880273238136],
#  ['2020-06-04', 115.96086400847457],
#  ['2020-06-05', 116.37751060904603],
#  ['2020-06-06', 116.66570784883112],
#  ['2020-06-07', 116.74010748415297],
#  ['2020-06-08', 116.9753070220665],
#  ['2020-06-09', 116.77645793415567],
#  ['2020-06-10', 116.75958642552618],
#  ['2020-06-11', 116.56330574764101],
#  ['2020-06-12', 116.24076765363802],
#  ['2020-06-13', 115.99006115228308],
#  ['2020-06-14', 115.96259305668084],
#  ['2020-06-15', 115.48306149857855],
#  ['2020-06-16', 115.79286552460181],
#  ['2020-06-17', 115.9765904389207],
#  ['2020-06-18', 115.89999886449229],
#  ['2020-06-19', 115.75421131574785],
#  ['2020-06-20', 115.52149271733397],
#  ['2020-06-21', 115.86449845378128],
#  ['2020-06-22', 116.01673975107221],
#  ['2020-06-23', 116.40295525143446],
# ...

# %%
visualize(pred_stock_PG)

# %% [markdown]
# ## Forcast GM Stock Price

# %%
# Read data from CSV and build training dataframe
df = pd.read_csv('dataset/GM.csv')
minmax = MinMaxScaler().fit(df.iloc[:, 4:5].astype('float32')) # Close index
df_log = minmax.transform(df.iloc[:, 4:5].astype('float32')) # Close index
df_log = pd.DataFrame(df_log)
df_train = df_log
df.shape, df_train.shape
# Out:
# ((253, 7), (253, 1))

# %%
# Forcasting the future price
pred_stock_GM = forecast()
# Out:
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x000001C1AE418F60>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# ...
# train loop:  66%|█████████████████████████████               | 198/300 [01:44<00:52,  1.96it/s, acc=97.1, cost=0.00256]
# ...
# ...
# train loop: 100%|████████████████████████████████████████████| 300/300 [02:41<00:00,  1.86it/s, acc=97.6, cost=0.00177]

# %%
# Check this model if stable, if True then keep the model. Otherwise, we need to retrain a model
sanity_check(pred_stock_GM)
# Out:
# True

# %%
# See the forcasted stock closing price
[list(i) for i in zip(date_ori, pred_stock_GM)][-30:]
# Out:
# [['2020-05-30', 25.967890358430868],
#  ['2020-05-31', 25.72400831827527],
#  ['2020-06-01', 25.505668082292217],
#  ['2020-06-02', 25.169791590906147],
#  ['2020-06-03', 25.11928043296644],
#  ['2020-06-04', 24.63066561055257],
#  ['2020-06-05', 24.193440314351754],
#  ['2020-06-06', 24.492225736097552],
#  ['2020-06-07', 24.19781564322215],
#  ['2020-06-08', 24.23043995273556],
#  ['2020-06-09', 24.538568451973386],
#  ['2020-06-10', 24.917635395698948],
#  ['2020-06-11', 25.0291549971734],
#  ['2020-06-12', 25.138889526904286],
#  ['2020-06-13', 24.934341976120713],
#  ['2020-06-14', 24.872555014615838],
#  ['2020-06-15', 25.00527895887403],
#  ['2020-06-16', 25.155835097199926],
#  ['2020-06-17', 24.89867108192008],
#  ['2020-06-18', 24.659098935318767],
#  ['2020-06-19', 24.446841889037756],
#  ['2020-06-20', 24.60433029760558],
#  ['2020-06-21', 24.633263023020817],
#  ['2020-06-22', 24.49704375737855],
#  ['2020-06-23', 24.368064160272002],
# ...

# %%
visualize(pred_stock_GM)
